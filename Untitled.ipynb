# %%
import matplotlib.pyplot as plt

x= [5,1,6,4]
y= [6,2,7,8]

plt.plot(x,y)

plt.xlabel('X Axis')
plt.ylabel('Y Axis')

#Title for the graph
plt.title('Grpah Project using Python')

plt.savefig('graph.png')

plot.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 16
#      12 plt.title('Grpah Project using Python')
#      14 plt.savefig('graph.png')
# ---> 16 plot.show()
#
# NameError: name 'plot' is not defined
